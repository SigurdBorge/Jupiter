# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# <h1> My Jupyter Notebook on IBM Watson Studio</h1>

# %% [markdown]
# <b>Sigurd Borge</b>
# <br>Student</br>

# %% [markdown]
# <em>I am intrested in Data science because it can help many people in different industries. </em>

# %% [markdown]
# <h3> In the code below I will introduce my name and age: </h3>

# %%
one = "Hello "
two = "World "
uno = "I am"
years = " 20 years old"
print(one + two + uno + years)
age = 2*10
print(age)
# Out:
# Hello World I am 20 years old
# 20

# %% [markdown]
# <img src="https://media.wired.com/photos/633f53b05ec45110c69a14e9/master/pass/the-super-mario-bros-movie_culture.jpg">
# <br></br>

# %%
numbers = [0, 1, 2, 3, 4, 5]
for number in numbers:
  print(number)
src = "https://github.com/SigurdBorge"
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
